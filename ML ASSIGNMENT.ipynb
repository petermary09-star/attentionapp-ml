# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#sns.load_dataset('attention.csv', on https://github.com/mwaskom/seaborn-data)

# %%
Attention = pd.read_csv('attention.csv')

# %%
Attention
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 5            5        6   divided          1    5.0
# 6            6        7   divided          1    5.0
# 7            7        8   divided          1    5.0
# 8            8        9   divided          1    2.0
# 9            9       10   divided          1    6.0
# 10          10       11   focused          1    6.0
# 11          11       12   focused          1    8.0
# 12          12       13   focused          1    6.0
# 13          13       14   focused          1    8.0
# 14          14       15   focused          1    8.0
# 15          15       16   focused          1    6.0
# 16          16       17   focused          1    7.0
# ...

# %% [markdown]
# #### Data Cleaning

# %%
Attention.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  60 non-null     int64
#  1   subject     60 non-null     int64
#  2   attention   60 non-null     object
#  3   solutions   60 non-null     int64
#  4   score       60 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.5+ KB

# %%
Attention.columns
# Out:
# Index(['Unnamed: 0', 'subject', 'attention', 'solutions', 'score'], dtype='object')

# %%
#Attention.drop(0, axis=1)

# %%
Attention.drop('Unnamed: 0', axis=1, inplace=True)

# %%
Attention
# Out:
#     subject attention  solutions  score
# 0         1   divided          1    2.0
# 1         2   divided          1    3.0
# 2         3   divided          1    3.0
# 3         4   divided          1    5.0
# 4         5   divided          1    4.0
# 5         6   divided          1    5.0
# 6         7   divided          1    5.0
# 7         8   divided          1    5.0
# 8         9   divided          1    2.0
# 9        10   divided          1    6.0
# 10       11   focused          1    6.0
# 11       12   focused          1    8.0
# 12       13   focused          1    6.0
# 13       14   focused          1    8.0
# 14       15   focused          1    8.0
# 15       16   focused          1    6.0
# 16       17   focused          1    7.0
# 17       18   focused          1    7.0
# 18       19   focused          1    5.0
# 19       20   focused          1    6.0
# 20        1   divided          2    4.0
# 21        2   divided          2    4.0
# ...

# %% [markdown]
# ### Features Selection

# %%
sns.pairplot(Attention)

# %%
sns.boxplot(data=Attention)
# Out:
# <Axes: >

# %%
y = Attention['score']

# %%
x = Attention[['subject', 'solutions']]

# %%
y
# Out:
# 0     2.0
# 1     3.0
# 2     3.0
# 3     5.0
# 4     4.0
# 5     5.0
# 6     5.0
# 7     5.0
# 8     2.0
# 9     6.0
# 10    6.0
# 11    8.0
# 12    6.0
# 13    8.0
# 14    8.0
# 15    6.0
# 16    7.0
# 17    7.0
# 18    5.0
# 19    6.0
# 20    4.0
# 21    4.0
# 22    5.0
# 23    7.0
# 24    5.0
# 25    5.0
# 26    4.5
# 27    7.0
# 28    3.0
# 29    5.0
# 30    5.0
# 31    9.0
# 32    5.0
# 33    8.0
# 34    8.0
# 35    8.0
# 36    7.0
# 37    8.0
# 38    6.0
# 39    6.0
# 40    7.0
# 41    5.0
# 42    6.0
# 43    5.0
# 44    8.0
# 45    6.0
# 46    6.0
# 47    8.0
# 48    7.0
# 49    6.0
# 50    6.0
# 51    8.0
# 52    9.0
# 53    7.0
# 54    7.0
# 55    7.0
# 56    6.0
# 57    6.0
# 58    6.0
# 59    5.0
# Name: score, dtype: float64

# %% [markdown]
# ### SPLIT DATA INTO TRAINING & TESTING

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=101)

# %% [markdown]
# ### Algorithm selection

# %%
### regressor

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# #### support vector machine regressor

# %%
svr_model = SVR()

# %%
svr_model.fit(X_train,y_train)
# Out:
# SVR()

# %%
prediction = model.predict(X_test)

# %%
print(y_test)
print(prediction)
# Out:
# 45    6.0
# 57    6.0
# 54    7.0
# 16    7.0
# 26    4.5
# 18    5.0
# 39    6.0
# 21    4.0
# 1     3.0
# 27    7.0
# 33    8.0
# 38    6.0
# 51    8.0
# 24    5.0
# 2     3.0
# Name: score, dtype: float64
# [5.29077052 6.60833559 6.96250069 6.8714224  5.25272568 6.45795152
#  6.14074581 4.95736551 4.83389769 5.4329164  6.89310963 6.42000942
#  6.54483003 5.0355351  4.82696412]

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %%
print('R2 Score:',r2_score(y_test,prediction))
# Out:
# R2 Score: 0.5209827301210048

# %%
print('MAE:', mean_absolute_error(y_test,prediction))
# Out:
# MAE: 0.8691987185461986

# %% [markdown]
# ### Linear Regression

# %%
lin_model = LinearRegression()

# %%
lin_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = lin_model.predict(X_test)

# %%
print('R2 Score:',r2_score(y_test,prediction))
print('MAE:', mean_absolute_error(y_test,prediction))
# Out:
# R2 Score: 0.41917093829972696
# MAE: 1.0614969365652964

# %% [markdown]
# #### RandomForest

# %%
rand_model = RandomForestRegressor()

# %%
rand_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
prediction = rand_model.predict(X_test)

# %%
print('R2 Score:',r2_score(y_test,prediction))
print('MAE:', mean_absolute_error(y_test,prediction))
# Out:
# R2 Score: 0.5768913649025069
# MAE: 0.796

# %% [markdown]
# ### Decision Tree

# %%
de_model = DecisionTreeRegressor()

# %%
de_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
prediction = de_model.predict(X_test)

# %%
print('R2 Score:',r2_score(y_test,prediction))
print('MAE:', mean_absolute_error(y_test,prediction))
# Out:
# R2 Score: 0.5194986072423398
# MAE: 0.7666666666666667

# %%
import pickle

# %%
with open('rand_model.pkl','wb') as f:
    pickle.dump(rand_model,f)
